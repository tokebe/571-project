# %%
import re
import pandas as pd
import numpy as np

from word2number import w2n

# %%
ufo_us = pd.read_csv("Data/ufo_data_us_cleaned_v1.csv")
ufo_non_us = pd.read_csv("Data/ufo_data_non_us_cleaned_v1.csv")

# %% [markdown]
# First, let's try and set a 'standard' capture to filter out 'easily' converted notations

# %%
standard = r"[0-9]+\+? *(?:m(?:in)?(?:ute)?s?\.?|s(?:ec)?(?:ond)?s?\.?|h(?:ou)?rs?\.?)"

us_weird_dur = ufo_us[~ufo_us["Duration"].str.contains(standard, na=True, flags=re.IGNORECASE)]["Duration"]

# %% [markdown]
# There are a few things we can do to normalize entries, such as remove "approx." some other things:
#
# - remove 'about'
# - replace a -> 1
# - replace 'all night'/'all day' -> 12 hours
# - word2num (one->1 etc)

# %%
ufo_us["Duration"].isna().sum()
# Out:
# 3015

# %%
# create a function to do these things
def fix_entries(x):
    x = str(x).lower()
    if re.search(r"[a-z]+ +(?:m(?:in)?(?:ute)?s?\.?|s(?:ec)?(?:ond)?s?\.?|h(?:ou)?rs?\.?)", x, flags=re.IGNORECASE):
        split = x.split(" ")
        try:
            y = str(w2n.word_to_num(split[0])) + " " + " ".join(split[1:])
            print("{} -> {}".format(x, y))
            x = y
        except ValueError:
            pass
    if re.search(r"than", x, flags=re.IGNORECASE):
        y = re.sub(r"than", "", x, flags=re.IGNORECASE)
        print("{} -> {}".format(x, y))
        x = y
    if re.search("a? ?few", x, flags=re.IGNORECASE):
        y = re.sub("a? ?few", "3", x, flags=re.IGNORECASE)
        print("{} -> {}".format(x, y))
        x = y
    if re.search("a? ?couple", x, flags=re.IGNORECASE):
        y = re.sub("a? ?couple", "2", x, flags=re.IGNORECASE)
        print("{} -> {}".format(x, y))
        x = y    
    if re.search("about", x, flags=re.IGNORECASE):
        y = re.sub("about", "", x, flags=re.IGNORECASE)
        print("{} -> {}".format(x, y))
        x = y
    if re.search(r"approx\.?", x, flags=re.IGNORECASE):
        y = re.sub(r"approx\.?", "", x, flags=re.IGNORECASE)
        print("{} -> {}".format(x, y))
        x = y
    if re.search(r"one", x, flags=re.IGNORECASE):
        y = re.sub(r"one", "1", x, flags=re.IGNORECASE)
        print("{} -> {}".format(x, y))
        x = y
    if re.search(r"all +(?:day|night)", x, flags=re.IGNORECASE):
        y = re.sub(r"all +(?:day|night)", "12 hours", x, flags=re.IGNORECASE)
        print("{} -> {}".format(x, y))
        x = y
    if re.search(r"an? ", x, flags=re.IGNORECASE):
        y = re.sub(r"an? ", "1 ", x, flags=re.IGNORECASE)
        print("{} -> {}".format(x, y))
        x = y
    
    return x

# %%
ufo_us["Duration"] = ufo_us["Duration"].apply(fix_entries)
ufo_us["Duration"].replace("nan", np.nan, inplace=True)
# Out:
# econds
# less than a second -> less  a second
# less  a second -> less  1 second
# all night -> 12 hours
# all night -> 12 hours
# 90 plus minutes -> 90 plus minutes
# twenty five seconds -> 20 five seconds
# a few minutes -> 3 minutes
# few seconds -> 3 seconds
# a few seconds, multiple o -> 3 seconds, multiple o
# few seconds -> 3 seconds
# all night -> 12 hours
# about 3 minutes ->  3 minutes
# an hour -> 1 hour
# a few seconds -> 3 seconds
# a few seconds -> 3 seconds
# one-half second -> 1 second
# ten seconds -> 10 seconds
# three hours -> 3 hours
# one minute -> 1 minute
# few seconds -> 3 seconds
# a few seconds -> 3 seconds
# few seconds -> 3 seconds
# few seconds -> 3 seconds
# less than 5 minutes -> less  5 minutes
# a couple of seconds -> 2 of seconds
# about 5 minutes ->  5 minutes
# twenty minutes -> 20 minutes
# five minutes -> 5 minutes
# a few minutes -> 3 minutes
# a couple of seconds -> 2 of seconds
# a couple of seconds -> 2 of seconds
# 30 minutes or so -> 30 minutes or so
# approx.3 hrs. -> 3 hrs.
# one minute -> 1 minute
# few seconds -> 3 seconds
# one minute -> 1 minute
# a few seconds -> 3 seconds
# about 5 minutes ->  5 minutes
# about a minute and a half ->  a minute and a half
#  a minute and a half ->  1 minute and 1 half
# one minute -> 1 minute
# 2 events one short one lo -> 2 events one short one lo
# 2 events one short one lo -> 2 events 1 short 1 lo
# few seconds -> 3 seconds
# couple of seconds -> 2 of seconds
# about 4 minutes ->  4 minutes
# twenty minutes -> 20 minutes
# about 5 seconds ->  5 seconds
# one minute -> 1 minute
# about a minute? ->  a minute?
#  a minute? ->  1 minute?
# five minutes -> 5 minutes
# > one hour -> > 1 hour
# over one hour -> over 1 hour
# about 10 minutes ->  10 minutes
# less than a minute -> less  a minute
# less  a minute -> less  1 minute
# a few minutes -> 3 minutes
# five minutes -> 5 minutes
# three minutes -> 3 minutes
# few minutes -> 3 minutes
# a few seconds. -> 3 seconds.
# a few seconds -> 3 seconds
# 5 min. approx. -> 5 min.
# 3 minutes approx. -> 3 minutes
# about 25 minutes ->  25 minutes
# few seconds -> 3 seconds
# few seconds -> 3 seconds
# half an hour -> half 1 hour
# all night/sometimes day -> 12 hours/sometimes day
# ten to twelve seconds -> 10 to twelve seconds
# few seconds -> 3 seconds
# less than a minute -> less  a minute
# less  a minute -> less  1 minute
# all night -> 12 hours
# one minute -> 1 minute
# about one minute ->  one minute
#  one minute ->  1 minute
# about a half hour off and ->  a half hour off and
#  a half hour off and ->  1 half hour off and
# few seconds -> 3 seconds
# 7 days straight -> 7 days straight
# five minutes -> 5 minutes
# less than 1 min -> less  1 min
# approx 5 min ->  5 min
# approx 3-5 min? ->  3-5 min?
# ten minutes -> 10 minutes
# about 3 minutes ->  3 minutes
# less than 1.5 minutes -> less  1.5 minutes
# twenty or thirty minutes -> 20 or thirty minutes
# 1 hour or more -> 1 hour or more
# about five minutes ->  five minutes
# two minutes -> 2 minutes
# over an hour -> over 1 hour
# less than a minute -> less  a minute
# less  a minute -> less  1 minute
# 15 min or more -> 15 min or more
# a few minutes -> 3 minutes
# few minutes -> 3 minutes
# less than 1 min -> less  1 min
# 1 hour(approx) -> 1 hour()
# over an hour -> over 1 hour
# few minutes -> 3 minutes
# approx 35 min ->  35 min
# few minutes -> 3 minutes
# about a minute and a half ->  a minute and a half
#  a minute and a half ->  1 minute and 1 half
# couple minutes -> 2 minutes
# no more than 10 seconds -> no more  10 seconds
# four seconds -> 4 seconds
# few minutes -> 3 minutes
# six minutes -> 6 minutes
# 3x each about 45 sec. -> 3x each  45 sec.
# about 1 minute ->  1 minute
# about 7 min ->  7 min
# few seconds -> 3 seconds
# a few seconds -> 3 seconds
# brief/a minute or so -> brief/1 minute or so
# one minute -> 1 minute
# about 30 seconds ->  30 seconds
# one hour -> 1 hour
# about 30 seconds ->  30 seconds
# few seconds -> 3 seconds
# less than 30 seconds -> less  30 seconds
# a few seconds -> 3 seconds
# brief, maybe a minute -> brief, maybe 1 minute
# a few seconds -> 3 seconds
# about 5 minutes ->  5 minutes
# approximately 1 minute -> imately 1 minute
# one minute -> 1 minute
# less then a minute -> less then 1 minute
# ten minutes -> 10 minutes
# going on an hour still th -> going on 1 hour still th
# few seconds -> 3 seconds
# approx. 12 minutes ->  12 minutes
# few minutes -> 3 minutes
# about 1 minute ->  1 minute
# few seconds -> 3 seconds
# 15 seconds then about 10  -> 15 seconds then  10
# 1 minute (approx) -> 1 minute ()
# two minutes -> 2 minutes
# one hour -> 1 hour
# few seconds -> 3 seconds
# a minute, maybe more -> 1 minute, maybe more
# one minute -> 1 minute
# one minute -> 1 minute
# a few minutes -> 3 minutes
# few seconds -> 3 seconds
# 1 and half min -> 1 and half min
# less than 1 hour -> less  1 hour
# maybe a minute -> maybe 1 minute
# 3 min. approx. -> 3 min.
# three minutes -> 3 minutes
# six minutes -> 6 minutes
# streaked by less than a s -> streaked by less  a s
# streaked by less  a s -> streaked by less  1 s
# a few minutes -> 3 minutes
# few minutes -> 3 minutes
# up to two hours about eve -> up to two hours  eve
# a few seconds. -> 3 seconds.
# an hour -> 1 hour
# less than a minute -> less  a minute
# less  a minute -> less  1 minute
# one hour -> 1 hour
# about 1 min. ->  1 min.
# few minutes -> 3 minutes
# less than minute -> less  minute
# about 10 minutes ->  10 minutes
# usually last a few second -> usually last 3 second
# few seconds -> 3 seconds
# 5 minutes (approx.) -> 5 minutes ()
# less than 1 min. -> less  1 min.
# seven minutes -> 7 minutes
# five minutes -> 5 minutes
# so far an hour -> so far 1 hour
# basically, all night -> basically, 12 hours
# less than 8 minutes -> less  8 minutes
# about 8 minutes ->  8 minutes
# one hour -> 1 hour
# about 5 minutes ->  5 minutes
# 4 within an hour -> 4 within an hour
# 4 within an hour -> 4 within 1 hour
# couple of seconds -> 2 of seconds
# 3 hours or more -> 3 hours or more
# few days -> 3 days
# 10 minutes approx -> 10 minutes
# seven minutes -> 7 minutes
# about 1 minute ->  1 minute
# few seconds -> 3 seconds
# few minutes -> 3 minutes
# none -> n1
# one hour -> 1 hour
# few minutes/in a car -> 3 minutes/in a car
# 3 minutes/in a car -> 3 minutes/in 1 car
# one minute -> 1 minute
# less then a minute -> less then 1 minute
# about 20 mins ->  20 mins
# about 30 mins ->  30 mins
# about 10to15 sec ->  10to15 sec
# about 1 minute ->  1 minute
# a few minutes -> 3 minutes
# ten seconds -> 10 seconds
# few seconds -> 3 seconds
# 45 seconds to one minute -> 45 seconds to one minute
# 45 seconds to one minute -> 45 seconds to 1 minute
# less than 1 second -> less  1 second
# constantly for a month -> constantly for 1 month
# approx. 5 min. ->  5 min.
# a few seconds -> 3 seconds
# 5 seconds approx -> 5 seconds
# less than a minute -> less  a minute
# less  a minute -> less  1 minute
# couple minutes -> 2 minutes
# few minutes -> 3 minutes
# more than 30 minutes -> more  30 minutes
# aleast an hour and half -> aleast 1 hour and half
# few minutes -> 3 minutes
# few seconds -> 3 seconds
# over a period of ~30 mins -> over 1 period of ~30 mins
# one minute -> 1 minute
# none -> n1
# one minute -> 1 minute
# approximately 15 mins -> imately 15 mins
# one minute -> 1 minute
# five to eight minutes -> 5 to eight minutes
# 45 minutes to an hour -> 45 minutes to an hour
# 45 minutes to an hour -> 45 minutes to 1 hour
# two minutes -> 2 minutes
# about 1 minute ->  1 minute
# approx 1 minute ->  1 minute
# less than 1 minute -> less  1 minute
# at least an hour -> at least 1 hour
# approximately 1 minute -> imately 1 minute
# approximately 1 minute -> imately 1 minute
# one minute -> 1 minute
# about 2 minutes ->  2 minutes
# approx. 1 min. ->  1 min.
# maybe  one minute -> maybe  1 minute
# all night -> 12 hours
# about 45 seconds ->  45 seconds
# fraction of a second -> fraction of 1 second
# one week -> 1 week
# all night -> 12 hours
# approx 5 seconds ->  5 seconds
# about 4 minutes ->  4 minutes
# about 3 minutes ->  3 minutes
# couple minutes -> 2 minutes
# a few minutes -> 3 minutes
# 10 minutes or so -> 10 minutes or so
# about 20 min ->  20 min
# just a couple of minutes -> just 2 of minutes
# less than 1 minute -> less  1 minute
# about 10 seconds ->  10 seconds
# few seconds -> 3 seconds
# just a few seconds -> just 3 seconds
# about 30 seconds ->  30 seconds
# approx. 3 hrs ->  3 hrs
# few seconds -> 3 seconds
# all night -> 12 hours
# less than 1 minute -> less  1 minute
# about a minute ->  a minute
#  a minute ->  1 minute
# few minutes -> 3 minutes
# 30 minutes or so -> 30 minutes or so
# about 5 minutes ->  5 minutes
# 3 minutes or so -> 3 minutes or so
# a split second -> 1 split second
# few minutes -> 3 minutes
# more than 5 min. -> more  5 min.
# all night -> 12 hours
# hurricane patricia after  -> hurricane patrici1 after
# about 10 minutes ->  10 minutes
# a few seconds -> 3 seconds
# less then a minute -> less then 1 minute
# about an hour. ->  an hour.
#  an hour. ->  1 hour.
# one minute -> 1 minute
# about at an estimate 15 m ->  at an estimate 15 m
#  at an estimate 15 m ->  at 1 estimate 15 m
# about 17 seconds ->  17 seconds
# less than 30 seconds -> less  30 seconds
# less than 1 minute -> less  1 minute
# approx 1min 30 sec ->  1min 30 sec
# 2 minute s -> 2 minute s
# less than 5 min -> less  5 min
# about 2 mins ->  2 mins
# about 3 seconds ->  3 seconds
# one minute -> 1 minute
# less than 10 minutes -> less  10 minutes
# few seconds -> 3 seconds
# a few seconds each -> 3 seconds each
# about 30 minutes ->  30 minutes
# less than 1 minute -> less  1 minute
# few seconds -> 3 seconds
# few minutes -> 3 minutes
# four minutes -> 4 minutes
# a minute or so -> 1 minute or so
# a few seconds -> 3 seconds
# five min -> 5 min
# about 5 sec. ->  5 sec.
# 30 seconds to one mintue -> 30 seconds to one mintue
# 30 seconds to one mintue -> 30 seconds to 1 mintue
# all day - still going on -> 12 hours - still going on
# all night -> 12 hours
# about 3 seconds ->  3 seconds
# approx. 05 sec ->  05 sec
# about 5 minutes ->  5 minutes
# ten minutes -> 10 minutes
# 30 plus minutes -> 30 plus minutes
# approx.20min -> 20min
# seemed like just a couple -> seemed like just 2
# two -tree minuts -> 2 -tree minuts
# around one minute -> around 1 minute
# 30 minutes still going -> 30 minutes still going
# about 5 minutes ->  5 minutes
# approx 1 min ->  1 min
# less than a full minute -> less  a full minute
# less  a full minute -> less  1 full minute
# less than a minute -> less  a minute
# less  a minute -> less  1 minute
# a few seconds -> 3 seconds
# less then a second -> less then 1 second
# 30 minutes (approx.) -> 30 minutes ()
# a few seconds -> 3 seconds
# about 8 seconds ->  8 seconds
# a few seconds -> 3 seconds
# three min. -> 3 min.
# this past couple of month -> this past2 of month
# approx 45 sec ->  45 sec
# 30 mins to and hour -> 30 mins to and hour
# two minutes -> 2 minutes
# few seconds -> 3 seconds
# approx. two minutes ->  two minutes
# about 5 seconds ->  5 seconds
# 1 minute or more -> 1 minute or more
# about 5 minutes ->  5 minutes
# hour and a half -> hour and 1 half
# all night -> 12 hours
# about 2 minutes ->  2 minutes
# few minutes -> 3 minutes
# an hour or 2 -> 1 hour or 2
# 30 may still be out there -> 30 may still be out there
# about 15 minutes ->  15 minutes
# 30 seconds or so -> 30 seconds or so
# a few seconds -> 3 seconds
# approx. 10 minutes ->  10 minutes
# all night -> 12 hours
# few seconds -> 3 seconds
# few minutes -> 3 minutes
# less than minute -> less  minute
# 5 seconds max -> 5 seconds max
# less then a minute -> less then 1 minute
# for about ten minutes -> for  ten minutes
# approx 3 minutes ->  3 minutes
# three hours -> 3 hours
# one minute -> 1 minute
# 2 seconds and saw mo -> 2 seconds and saw mo
# 5 minutes or more -> 5 minutes or more
# 10 minutes or more -> 10 minutes or more
# less than 10 minutes but  -> less  10 minutes but
# one to minutes -> 1 to minutes
# a few minutes -> 3 minutes
# five seconds -> 5 seconds
# 9 or more seconds -> 9 or more seconds
# about 20 min ->  20 min
# 20 plus minutes -> 20 plus minutes
# few minutes -> 3 minutes
# one minute -> 1 minute
# all night -> 12 hours
# 15 min approx -> 15 min
# about 1min ->  1min
# less than 5 minutes -> less  5 minutes
# approx. 15 mins ->  15 mins
# a few minutes -> 3 minutes
# less than one minute -> less  one minute
# less  one minute -> less  1 minute
# all night -> 12 hours
# longer than 5 minutes -> longer  5 minutes
# about 9 minutes ->  9 minutes
# all night -> 12 hours
# about 10 mins. ->  10 mins.
# five minutes -> 5 minutes
# 1 minute or more -> 1 minute or more
# approx. 40 sec. ->  40 sec.
# about 10 min. ->  10 min.
# about 8 seconds ->  8 seconds
# few mins -> 3 mins
# approx. 2 hrs. ->  2 hrs.
# about 15 minutes ->  15 minutes
# less than a minute -> less  a minute
# less  a minute -> less  1 minute
# 2 and a half  minutes -> 2 and a half  minutes
# 2 and a half  minutes -> 2 and 1 half  minutes
# few seconds -> 3 seconds
# few minutes -> 3 minutes
# one hour -> 1 hour
# one hour -> 1 hour
# twenty minutes -> 20 minutes
# about 4minutes ->  4minutes
# about 2 minutes ->  2 minutes
# approx.20 ,min -> 20 ,min
# 45 minutes or more -> 45 minutes or more
# approx 2 minutes ->  2 minutes
# less than a minute -> less  a minute
# less  a minute -> less  1 minute
# all day -> 12 hours
# one minute -> 1 minute
# about an hour ->  an hour
#  an hour ->  1 hour
# about 7 seconds ->  7 seconds
# a few minutes -> 3 minutes
# all day -> 12 hours
# one hour-ish -> 1 hour-ish
# approx  18 min ->   18 min
# over an hr in a half -> over 1 hr in 1 half
# 10 seconds maybe -> 10 seconds maybe
# three minutes -> 3 minutes
# about 3 minutes ->  3 minutes
# a few seconds -> 3 seconds
# 5 plus sec -> 5 plus sec
# one hour -> 1 hour
# all night -> 12 hours
# 30 seconds or so -> 30 seconds or so
# 1 minute or more -> 1 minute or more
# maybe an hour -> maybe 1 hour
# about a half hour ->  a half hour
#  a half hour ->  1 half hour
# few seconds -> 3 seconds
# less than 90seconds -> less  90seconds
# three minutes -> 3 minutes
# one second -> 1 second
# approx 1 minute ->  1 minute
# a few minutes -> 3 minutes
# 30 minutes or more -> 30 minutes or more
# about 3 minutes ->  3 minutes
# a few seconds -> 3 seconds
# about a 1 min ->  a 1 min
#  a 1 min ->  1 1 min
# few seconds -> 3 seconds
# about 20 mins. ->  20 mins.
# five minutes -> 5 minutes
# approx. 1 min ->  1 min
# about 4 minutes ->  4 minutes
# a few minutes -> 3 minutes
# approx 6 minutes ->  6 minutes
# less than 30 seconds -> less  30 seconds
# a few seconds -> 3 seconds
# about a minute ->  a minute
#  a minute ->  1 minute
# ten minutes -> 10 minutes
# about 1 hour ->  1 hour
# about 20 seconds ->  20 seconds
# less than 5 minutes -> less  5 minutes
# few minutes -> 3 minutes
# about 5 min ->  5 min
# ten min -> 10 min
# 3 min (approx.) -> 3 min ()
# at leat one hour and goin -> at leat 1 hour and goin
# about 30 sec. ->  30 sec.
# few seconds -> 3 seconds
# a couple seconds -> 2 seconds
# about an hour ->  an hour
#  an hour ->  1 hour
# a few minutes -> 3 minutes
# an hour + -> 1 hour +
# few seconds -> 3 seconds
# 10 minutes maybe -> 10 minutes maybe
# about  1 minute ->   1 minute
# about a minute ->  a minute
#  a minute ->  1 minute
# two minutes -> 2 minutes
# around a minute -> around 1 minute
# approx. 2 min. ->  2 min.
# about 1 min. ->  1 min.
# approximately 3 and 1/2 m -> imately 3 and 1/2 m
# 4 min. approx. -> 4 min.
# 2 seconds max -> 2 seconds max
# reoccurring for about las -> reoccurring for  las
# one hour+ -> 1 hour+
# about 5-7 min. ->  5-7 min.
# all night -> 12 hours
# about 10 seconds ->  10 seconds
# about 4 minutes ->  4 minutes
# about 5 mins long ->  5 mins long
# nearly an hour -> nearly 1 hour
# approx. 50 seconds ->  50 seconds
# a few minutes -> 3 minutes
# one minute -> 1 minute
# all night -> 12 hours
# 1 minute or so... -> 1 minute or so...
# one picture frame -> 1 picture frame
# about 1 minute ->  1 minute
# few mins -> 3 mins
# five hours -> 5 hours
# about 2 minutes ->  2 minutes
# one minute -> 1 minute
# two hours -> 2 hours
# about 5 minutes ->  5 minutes
# a few seconds -> 3 seconds
# a few seconds -> 3 seconds
# ten seconds -> 10 seconds
# all night -> 12 hours
# approx. 2 minutes ->  2 minutes
# about 5 minutes ->  5 minutes
# 1 minute approximately -> 1 minute imately
# approx 10-15 sec. ->  10-15 sec.
# not long maybe a minute -> not long maybe 1 minute
# a few seconds -> 3 seconds
# about 20 minutes ->  20 minutes
# a few minutes -> 3 minutes
# a few seconds -> 3 seconds
# about 3 minutes ->  3 minutes
# one hour -> 1 hour
# approx 5 min ->  5 min
# one hour -> 1 hour
# approx half hour ->  half hour
# thirty minutes -> 30 minutes
# less than a minute -> less  a minute
# less  a minute -> less  1 minute
# a few seconds -> 3 seconds
# about 5 minutes ->  5 minutes
# couple minutes + -> 2 minutes +
# 3 minutes approx. -> 3 minutes
# about one hour and fiftee ->  one hour and fiftee
#  one hour and fiftee ->  1 hour and fiftee
# approx. 7 min. ->  7 min.
# ten minutes -> 10 minutes
# couple seconds -> 2 seconds
# ten minutes -> 10 minutes
# one hour plus -> 1 hour plus
# 5 min. approx -> 5 min.
# less than 1 min -> less  1 min
# about 10 minutes ->  10 minutes
# about one minute ->  one minute
#  one minute ->  1 minute
# approximately 10 minutes -> imately 10 minutes
# approx. 2min ->  2min
# 4 to five seconds -> 4 to five seconds
# two seconds -> 2 seconds
# about 5 minutes ->  5 minutes
# 15 minutes or so -> 15 minutes or so
# about 10min ->  10min
# all night -> 12 hours
# about half an hour ->  half an hour
#  half an hour ->  half 1 hour
# approx. 3 minutes ->  3 minutes
# ten minutes -> 10 minutes
# few minutes -> 3 minutes
# about 5 seconds ->  5 seconds
# a few seconds -> 3 seconds
# one hour -> 1 hour
# about 30 minutes ->  30 minutes
# seven seconds -> 7 seconds
# 3 hours still happening r -> 3 hours still happening r
# 1 hour or so -> 1 hour or so
# 2 plus hours ongoing righ -> 2 plus hours ongoing righ
# 90 seconds (approx.) -> 90 seconds ()
# all night -> 12 hours
# one hour -> 1 hour
# five minutes -> 5 minutes
# all night and still conti -> 12 hours and still conti
# 3 mins approx -> 3 mins
# 5 minutes or so -> 5 minutes or so
# one minute -> 1 minute
# approx. 5 minutes ->  5 minutes
# 1 hour or more -> 1 hour or more
# a few minutes -> 3 minutes
# a few seconds -> 3 seconds
# ten minutes -> 10 minutes
# 45 seconds or so -> 45 seconds or so
# few minutes -> 3 minutes
# a few minutes -> 3 minutes
# a few minutes -> 3 minutes
# approx 20 min ->  20 min
# 15 minutes still there -> 15 minutes still there
# all night -> 12 hours
# about 8 seconds ->  8 seconds
# less than 1 second -> less  1 second
# one minute -> 1 minute
# less than 5 minutes -> less  5 minutes
# about 1 minute ->  1 minute
# less than minute -> less  minute
# approx. 1 minute ->  1 minute
# about four minutes ->  four minutes
# 5 min or so -> 5 min or so
# 5 minutes approx -> 5 minutes
# approx 5 mins ->  5 mins
# two or three seconds -> 2 or three seconds
# 45 min hour -> 45 min hour
# approx 1min ->  1min
# few minutes -> 3 minutes
# few hours -> 3 hours
# less than a minute -> less  a minute
# less  a minute -> less  1 minute
# approx 10 min ->  10 min
# few seconds -> 3 seconds
# 15 plus minutes -> 15 plus minutes
# 15 minutes so far -> 15 minutes so far
# twenty minutes -> 20 minutes
# few seconds -> 3 seconds
# seven minutes -> 7 minutes
# few minutes -> 3 minutes
# few minutes -> 3 minutes
# about 5-10mins ->  5-10mins
# about 1 minute ->  1 minute
# about one minute ->  one minute
#  one minute ->  1 minute
# about 3-4 minutes ->  3-4 minutes
# about 5 seconds ->  5 seconds
# over a half hour -> over 1 half hour
# about half an hour ->  half an hour
#  half an hour ->  half 1 hour
# few minutes -> 3 minutes
# one hour -> 1 hour
# few seconds -> 3 seconds
# less than 15 minutes -> less  15 minutes
# less than 5 seconds -> less  5 seconds
# about 30 seconds ->  30 seconds
# two minutes -> 2 minutes
# five minutes -> 5 minutes
# few minutes -> 3 minutes
# a few minutes -> 3 minutes
# few seconds -> 3 seconds
# five min -> 5 min
# 2 minutes approx. -> 2 minutes
# about 3 min. ->  3 min.
# about 2 minutes ->  2 minutes
# few minutes -> 3 minutes
# a second -> 1 second
# two to three min. -> 2 to three min.
# a few seconds -> 3 seconds
# ten minutes -> 10 minutes
# all night -> 12 hours
# all night all summer -> 12 hours all summer
# all night all summer -> 12 hours all summer
# few minutes -> 3 minutes
# approx. 4 min. ->  4 min.
# few minutes -> 3 minutes
# a few second -> 3 second
# approx. 3 minutes ->  3 minutes
# approx 10 min ->  10 min
# 30 minutes (approx.) -> 30 minutes ()
# approx. 1 minute ->  1 minute
# less than one half hour. -> less  one half hour.
# less  one half hour. -> less  1 half hour.
# three minutes -> 3 minutes
# more time than i had to s -> more time  i had to s
# les than a minute -> les  a minute
# les  a minute -> les  1 minute
# a few seconds -> 3 seconds

# %%
standard = r"[0-9]+\+? *(?:m(?:in)?(?:ute)?s?\.?|s(?:ec)?(?:ond)?s?\.?|h(?:ou)?rs?\.?)"

us_weird_dur_fix = ufo_us[~ufo_us["Duration"].str.contains(standard, na=True, flags=re.IGNORECASE)]["Duration"]

# %%
us_fix_useable = ufo_us[ufo_us["Duration"].str.contains(standard, na=False, flags=re.IGNORECASE)]["Duration"]

# %% [markdown]
# Ok, now that we have a general way to get most cases, let's apply it to replace everything in the dataframe

# %%
def to_seconds(x):
    mults = {
        r"mo(?:nths?)?": int(2.628e+6),
        r"m(?:in)?(?:ute)?s?": 60,
        r"h(?:ou)?rs?": 60*60,
        r"d(?:ays?)?": 60*60*24,
        r"y(?:ea)?rs?": int(3.154e+7),
        r"s(?:ec)?(?:ond)?s?": 1,
    }
    x = str(x).lower()
    match = re.search(r"([0-9]+-)?([0-9]+)\+? *(m(?:in)?(?:ute)?s?|h(?:ou)?rs?|d(?:ays?)?|mo(?:nths?)?|y(?:ea)?rs?|s(?:ec)?(?:ond)?s?)\.?", x, flags=re.IGNORECASE)
    if match:
        if match.groups()[0] is not None:
            number = (float(match.groups()[0][:-1]) + float(match.groups()[1])) / 2
        else:
            number = float(match.groups()[1])
        mult = [m for r, m in mults.items() if re.search(r, match.groups()[2], flags=re.IGNORECASE)][0]


        return number * mult
    else:
        return np.nan

# %%
ufo_us["Duration"] = ufo_us["Duration"].apply(to_seconds)

# %%
ufo_us.to_csv("ufo_data_us_cleaned_v2.csv", index=False)

# %%
ufo_non_us["Duration"] = ufo_non_us["Duration"].apply(fix_entries)
ufo_non_us["Duration"].replace("nan", np.nan, inplace=True)
ufo_non_us["Duration"] = ufo_non_us["Duration"].apply(to_seconds)
ufo_non_us.to_csv("ufo_data_non_us_cleaned_v2.csv", index=False)
# Out:
# less than 1 second -> less  1 second
# 20 min approx -> 20 min
# approx 2 minutes ->  2 minutes
# five minutes -> 5 minutes
# flyby approx 20 sec. -> flyby  20 sec.
# about 15 minutes each tim ->  15 minutes each tim
# none -> n1
# about 10 minutes ->  10 minutes
# ten minutes -> 10 minutes
# half an hour -> half 1 hour
# less than  2 min -> less   2 min
# few seconds -> 3 seconds
# few seconds -> 3 seconds
# none -> n1
# less than 2 hours -> less  2 hours
# more than ten minutes -> more  ten minutes
# few seconds -> 3 seconds
# about 10 min ->  10 min
# less than a minute -> less  a minute
# less  a minute -> less  1 minute
# about 3 or 4 hours. ->  3 or 4 hours.
# at least one hour -> at least 1 hour
# approx 2hrs ->  2hrs
# all night -> 12 hours
# few minutes -> 3 minutes
# approx 1 hour ->  1 hour
# about 15 sec ->  15 sec
# half an hour -> half 1 hour
# a few minutes, maybe 10 m -> 3 minutes, maybe 10 m
# approx 1 minute ->  1 minute
# two minutes -> 2 minutes
# greater than 10 minutes,  -> greater  10 minutes,
# all night -> 12 hours
# five minutes -> 5 minutes
# unsure, few minutes -> unsure,3 minutes
# only seen for a moment. -> only seen for 1 moment.
# all night til sunrise -> 12 hours til sunrise
# one hour + -> 1 hour +
# 45 minutes (approximately -> 45 minutes (imately
# on and off two- one half  -> on and off two- 1 half
# few minutes -> 3 minutes
# few seconds -> 3 seconds
# few minutes -> 3 minutes
# few second -> 3 second
# few seconds -> 3 seconds
# few minutes, i jumped on  -> 3 minutes, i jumped on
# ? witnessed for about 1 m -> ? witnessed for  1 m
# a few minutes -> 3 minutes
# approx.10 seconds -> 10 seconds
# 1/2 a minute -> 1/2 1 minute
# less than one minute -> less  one minute
# less  one minute -> less  1 minute
# one minute -> 1 minute
# about 2-3sec. ->  2-3sec.
# 5 min. maybe more -> 5 min. maybe more
# a couple hours -> 2 hours
# one hour -> 1 hour
# few seconds -> 3 seconds
# all night -> 12 hours
# 2 an a half minutes -> 2 an a half minutes
# 2 an a half minutes -> 2 1 1 half minutes
# 2 min. approx -> 2 min.
# about 10 secs. ->  10 secs.
# few seconds -> 3 seconds
# approx 12 seconds ->  12 seconds
# approxmately 2 minutes -> mately 2 minutes
# 6 sec. approx. -> 6 sec.
# about 10 seconds ->  10 seconds
# few hours -> 3 hours
# one minute -> 1 minute
# one hour -> 1 hour
# about 30 seconds ->  30 seconds
# few minutes -> 3 minutes
# 45 minutes (approx) -> 45 minutes ()
# none -> n1
# two minutes or three -> 2 minutes or three
# a minute or so -> 1 minute or so
# 35 sec approx -> 35 sec
# a minute -> 1 minute
# 15 minutes or more -> 15 minutes or more
# few seconds -> 3 seconds
# approx 10 seconds ->  10 seconds
# none -> n1
# all night -> 12 hours
# over a few months -> over 3 months
# few seconds of movement -> 3 seconds of movement
# a few minutes -> 3 minutes
# a few seconds -> 3 seconds
# 5 seconds multiple times -> 5 seconds multiple times
# going on for a while and  -> going on for 1 while and
# less than 1 minute -> less  1 minute
# about 10 minutes ->  10 minutes
# more than 2minuts -> more  2minuts
# approx 20-30 mins ->  20-30 mins
# one minute -> 1 minute
# ongoing more than an hour -> ongoing more  an hour
# ongoing more  an hour -> ongoing more  1 hour
# ten minutes -> 10 minutes
# few seconds -> 3 seconds
# about 5 minutes ->  5 minutes
# less than one second -> less  one second
# less  one second -> less  1 second
# three minutes -> 3 minutes
# three minutes -> 3 minutes
# about 6secs ->  6secs
# approx 1 1/2 mins ->  1 1/2 mins
# 7 seconds (approx.) -> 7 seconds ()
# approx 20 mins ->  20 mins
# a few seconds -> 3 seconds
# few seconds -> 3 seconds
# 1 and a half minute -> 1 and a half minute
# 1 and a half minute -> 1 and 1 half minute
# forty minutes -> 40 minutes
# over one hour -> over 1 hour
# 5 minutes (approx.) -> 5 minutes ()
# one minute -> 1 minute
# few seconds -> 3 seconds
# few minutes -> 3 minutes
# blink of an eye -> blink of 1 eye
# 8min and can still see it -> 8min and c1 still see it
# one minute -> 1 minute
# few seconds -> 3 seconds
# 10 minutes or so -> 10 minutes or so
# ca 1seconds -> c1 1seconds
# one and half hour -> 1 and half hour
# less then a minute -> less then 1 minute
# coming from a club -> coming from 1 club
# four minutes-ish -> 4 minutes-ish
# about 5 mins ->  5 mins
# two minutes -> 2 minutes
# about half a minute ->  half a minute
#  half a minute ->  half 1 minute
# about 4 seconds ->  4 seconds
# about half an hour ->  half an hour
#  half an hour ->  half 1 hour
# about 30sec ->  30sec
# few seconds -> 3 seconds
# one hour -> 1 hour
# about 1 hr ->  1 hr
# about 4 mins ->  4 mins
# less than 1 minutes -> less  1 minutes
# 4 mins approx -> 4 mins
# 1 minute approx -> 1 minute
# 1 minute approx -> 1 minute
# about 30 seconds ->  30 seconds
# blink of an eye -> blink of 1 eye
# about 1 hour ->  1 hour
# few seconds -> 3 seconds
# 2 1/2 hours or more -> 2 1/2 hours or more
# approx. 20 sec. ->  20 sec.
# 30sec to a min -> 30sec to 1 min
# 1 minute approx -> 1 minute
# all day -> 12 hours
# 5 mins. approx. -> 5 mins.
# few seconds -> 3 seconds
# couple of minuits -> 2 of minuits
# few seconds -> 3 seconds
# two minutes -> 2 minutes
# less than a minute -> less  a minute
# less  a minute -> less  1 minute
# a bout 3 minutes -> 1 bout 3 minutes
# a couple of hours -> 2 of hours
# few minutes -> 3 minutes
# 15 minutes approx -> 15 minutes
# approx.30 min. -> 30 min.
# 5 minutes approx -> 5 minutes
# approx 3 minutes ->  3 minutes
# about 7 mins ->  7 mins
# few minutes -> 3 minutes
# 30 mins(approx) -> 30 mins()
# approx. 30sec ->  30sec
# one minute -> 1 minute
# a picture shot -> 1 picture shot
# one hour -> 1 hour
# one minute -> 1 minute
# one min -> 1 min
# 2 minutes or so -> 2 minutes or so
# a few minutes -> 3 minutes
# 20 minutes or more -> 20 minutes or more
# one minute -> 1 minute
# 1 and half min -> 1 and half min
# approx 10-15 mins ->  10-15 mins
# approx. 1hr ->  1hr
# three minutes -> 3 minutes
# about 20 mins ->  20 mins
# less than 1 second -> less  1 second
# 20 min approx -> 20 min
# approx 2 minutes ->  2 minutes
# five minutes -> 5 minutes
# flyby approx 20 sec. -> flyby  20 sec.
# about 15 minutes each tim ->  15 minutes each tim
# none -> n1
# about 10 minutes ->  10 minutes
# ten minutes -> 10 minutes
# half an hour -> half 1 hour
# less than  2 min -> less   2 min
# few seconds -> 3 seconds
# few seconds -> 3 seconds
# none -> n1
# less than 2 hours -> less  2 hours
# more than ten minutes -> more  ten minutes
# few seconds -> 3 seconds
# about 10 min ->  10 min
# less than a minute -> less  a minute
# less  a minute -> less  1 minute
# about 3 or 4 hours. ->  3 or 4 hours.
# at least one hour -> at least 1 hour
# approx 2hrs ->  2hrs
# all night -> 12 hours
# few minutes -> 3 minutes
# approx 1 hour ->  1 hour
# half an hour -> half 1 hour
# approx 1 minute ->  1 minute
# two minutes -> 2 minutes
# greater than 10 minutes,  -> greater  10 minutes,
# few seconds -> 3 seconds
# all night -> 12 hours
# unsure, few minutes -> unsure,3 minutes
# only seen for a moment. -> only seen for 1 moment.
# all night til sunrise -> 12 hours til sunrise
# one hour + -> 1 hour +
# 45 minutes (approximately -> 45 minutes (imately
# on and off two- one half  -> on and off two- 1 half
# few minutes -> 3 minutes
# few seconds -> 3 seconds
# few minutes -> 3 minutes
# few second -> 3 second
# few seconds -> 3 seconds
# few minutes, i jumped on  -> 3 minutes, i jumped on
# few minutes, i jumped on  -> 3 minutes, i jumped on
# few minutes, i jumped on  -> 3 minutes, i jumped on
# ? witnessed for about 1 m -> ? witnessed for  1 m
# a few minutes -> 3 minutes
# approx.10 seconds -> 10 seconds
# 1/2 a minute -> 1/2 1 minute
# less than one minute -> less  one minute
# less  one minute -> less  1 minute
# less than one minute -> less  one minute
# less  one minute -> less  1 minute
# less than one minute -> less  one minute
# less  one minute -> less  1 minute
# one minute -> 1 minute
# about 2-3sec. ->  2-3sec.
# 5 min. maybe more -> 5 min. maybe more
# a couple hours -> 2 hours
# approx. 4 mins ->  4 mins
# few seconds -> 3 seconds
# one minute -> 1 minute
# all night -> 12 hours
# 2 an a half minutes -> 2 an a half minutes
# 2 an a half minutes -> 2 1 1 half minutes
# 2 min. approx -> 2 min.
# about 10 secs. ->  10 secs.
# few seconds -> 3 seconds
# approx 12 seconds ->  12 seconds
# approxmately 2 minutes -> mately 2 minutes
# 6 sec. approx. -> 6 sec.
# about 4 minutes ->  4 minutes
# all night -> 12 hours
# about 10 seconds ->  10 seconds
# few hours -> 3 hours
# one minute -> 1 minute
# one hour -> 1 hour
# about 30 seconds ->  30 seconds
# few minutes -> 3 minutes
# 45 minutes (approx) -> 45 minutes ()
# none -> n1
# two minutes or three -> 2 minutes or three
# a minute or so -> 1 minute or so
